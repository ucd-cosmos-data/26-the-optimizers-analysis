# %% [markdown]
# ## 1. Depression

# %%
import requests
import pandas as pd

url = "https://data.cdc.gov/resource/i46a-9kgh.json"
params = {
    "#select": "stateabbr,countryname,countryfips,DEPRESSION_CrudePrev",
    "stateabbr": "CA"
}
r = requests.get(url, params=params)
r.raise_for_status()

depression_ca = pd.DataFrame(r.json())
